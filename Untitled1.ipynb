# %%
 
#Q.1) List and  it default functions
  ----->
  List in Python are ordered and have a definite count.
  The elements in a list are indexed according to a definite  sequence and the indexing of a list is done with 0 being the first index.
  Each element in the list has its definite place in the list. which allows
  duplicating of elements in the list,with each element  having  its own  distinct place and credibility.
 
  Default functions are:
  1)append()
  2)remove()
  3)insert()
  4)pop()
  5)clear()
  6)index()
  7)extend()
  8)sort()
  9)reverse()
  10)len()
Q.2) Dictionary and its default functions
 ------>
 A dictionary is a collection which is unordered, changeable and indexed. 
 In python dictionaries are written with curly brackets, and they have keys and values
 
 
 Default functions:
 
1)keys()
2)get()
3)items()
4)clear()
5)pop()
6)update()
#Q3) Sets and default functions
----->
A set is a collection which is unordered and unindexed. In Python sets are written with curly brackets.
 
 
Default functions:
1) difference()
2)clear()
3)copy()
4)intersection()
5)discard()
#Q4) Tuple and explore its default functions
----->
A tuple is a collection which is 0ordered and unchangeable.
In Phython tuples are written with round brackers. 
 
Default  functions:
1)count()
2)index()
 
#Q5)String and explore default function
----> String literals in python are surrounded by either single
quotation marks, or double quotation marks. 
Ex.
'hello' is the same as "hello"
 
 
Default functions :
1)len()
2)ascii()
3)bool()
4)bytes()
5)hash()
6)id()
7)int()
8)slice()
9)ord()
10)map()
# Out:
#   File "<ipython-input-7-291ffd174de8>", line 3
#     ----->
#     ^
# IndentationError: unexpected indent
